# %%
import ultralytics
import os

# %%
os.chdir("..")

# %%
model = ultralytics.YOLO('best.onnx')  # load a pretrained YOLOv11l model
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.

# %%
result = model.predict("data/Football2025/RBK-AALESUND/data/images/train/frame_000003.png", conf=0.01, imgsz=1280)
# Out:
# image 1/1 /Users/krisnol/Documents/Skole/Semester 9/Visuel Intelligens/sport-tracking/data/Football2025/RBK-AALESUND/data/images/train/frame_000003.png: 1280x1280 22 players, 1 ball, 2511.0ms
# Speed: 11.6ms preprocess, 2511.0ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)

# %%
result[0].show()

# %%
results = model.track(
    source="data/Football2025/RBK-BODO/part2/matchvideo_part2.mp4", 
    conf=0.1, 
    iou=0.5,
    imgsz=1280,
    show=True
)
